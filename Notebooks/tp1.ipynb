# %%
import pandas as pd

# %%
csv1 = pd.read_csv("C:/Users/277840/MLops/Notebooks/Data/restaurant_1_week_002.csv")
csv2 = pd.read_csv("C:/Users/277840/MLops/Notebooks/Data/restaurant_1_week_007.csv")

# %%
csv1
# Out:
#     Order Number           Order Date               Item Name  Quantity  \
# 0           1388  2015-01-10 20:12:00           Onion Chutney         1
# 1           1388  2015-01-10 20:12:00              Mint Sauce         1
# 2           1388  2015-01-10 20:12:00             Lime Pickle         1
# 3           1388  2015-01-10 20:12:00                 Paratha         1
# 4           1387  2015-01-10 16:55:00             Onion Bhaji         1
# 5           1386  2015-01-10 16:28:00             Onion Bhaji         1
# 6            630  2015-01-09 14:42:00             Onion Bhaji         1
# 7           1385  2015-01-10 15:19:00  Tandoori Chicken (1/4)         1
# 8           1385  2015-01-10 15:19:00        Vegetable Samosa         1
# 9           1382  2015-01-10 10:49:00        Vegetable Samosa         1
# 10          1382  2015-01-10 10:49:00  Tandoori Chicken (1/4)         1
# 11          1376  2015-01-10 10:02:00        Vegetable Samosa         1
# ...

# %%
csv2
# Out:
#     Order Number           Order Date               Item Name  Quantity  \
# 0           1397  2015-02-10 14:38:00           Spicy Papadum         1
# 1           1403  2015-02-10 17:29:00                 Paratha         1
# 2           1403  2015-02-10 17:29:00            Coke 1.5 ltr         1
# 3           1403  2015-02-10 17:29:00              Lemon Rice         1
# 4           1402  2015-02-10 16:39:00             Onion Bhaji         1
# 5           1397  2015-02-10 14:38:00             Onion Bhaji         1
# 6           1397  2015-02-10 14:38:00           COBRA (330ML)         1
# 7           1390  2015-02-10 14:05:00             Onion Bhaji         2
# 8           1389  2015-02-10 10:29:00             Onion Bhaji         1
# 9           1403  2015-02-10 17:29:00        Vegetable Samosa         1
# 10          1403  2015-02-10 17:29:00  Tandoori Chicken (1/4)         1
# 11          1390  2015-02-10 14:05:00        Vegetable Samosa         1
# ...

# %%
csv1['Revenue'] = csv1['Quantity'] * csv1['Product Price']

# %%
# Out:
# C:\Users\277840\AppData\Local\Temp\ipykernel_16964\2687133453.py:1: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   csv1_hourly = csv1.resample('H', on='Order Date').sum()['Revenue']
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 csv1_hourly = csv1.resample('H', on='Order Date').sum()['Revenue']
#       3 # Afficher les premières lignes pour vérifier
#       4 print(csv1_hourly.head())
#
# File C:\Logiciels\anaconda3\Lib\site-packages\pandas\core\generic.py:9768, in NDFrame.resample(self, rule, axis, closed, label, convention, kind, on, level, origin, offset, group_keys)
#    9765 else:
#    9766     convention = "start"
# -> 9768 return get_resampler(
#    9769     cast("Series | DataFrame", self),
#    9770     freq=rule,
#    9771     label=label,
#    9772     closed=closed,
# ...

# %%
df_hourly = df_hourly.reset_index()
df_hourly.columns = ['ds', 'y']

print(df_hourly.head())
